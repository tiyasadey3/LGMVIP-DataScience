# %% [markdown]
# <a href="https://colab.research.google.com/github/tiyasadey3/LGMVIP-DataScience/blob/main/Task_4_Beginner_level_pancil_sketch_TIYASA_DEY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore**

# %% [markdown]
# ## **Beginner level task :**

# %% [markdown]
# ## **TASK 4 -Image to Pencil Sketch with Python**

# %% [markdown]
# ## **AUTHOR : TIYASA DEY**

# %% [markdown]
# ## **Importing required Libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## **Reading the Original Image**

# %%
image=cv2.imread("/content/sunflower.jpg")
original_image =cv2.resize(image, (700, 500))
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F6A64FD2550>

# %% [markdown]
# ## **Convert the RBG image to grayscale image**

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F6A64F94C50>

# %% [markdown]
# ## **Inverted the grayscale image**

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F6A64FD2DD0>

# %% [markdown]
# ## **Apply a Guassian Blur**

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F6A64FA1A90>

# %% [markdown]
# ## **Mixing the gray scale image with inverted blurry image**

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)

cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F6A66033AD0>

# %% [markdown]
# ## **Original image and pancil sketch image**

# %%
cv2_imshow(original_image)

cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F6A64FDD990>
# <PIL.Image.Image image mode=L size=700x500 at 0x7F6A64F945D0>
